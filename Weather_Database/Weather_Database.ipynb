# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random Lat and Lng combinations

lats= np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs= np.random.uniform(low=-90.000, high=90.000, size=2000)

# %%
#Iterate over several iterables in parallel, producing tuples with an item from each one.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5d97052749c403721dc478d41cd980f1

# %%
#city_weather.keys()

# %%
#city_weather['weather']

# %%
#city_weather['weather'][0]['description']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                           "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alto longa
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | polyarnyy
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | rovaniemi
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | saubara
# Processing Record 10 of Set 1 | mabama
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | havoysund
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | savinka
# Processing Record 16 of Set 1 | aripuana
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | verkhnyaya inta
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | marsabit
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | belmonte
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | santo antonio do ica
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | cayenne
# Processing Record 29 of Set 1 | gostyn
# Processing Record 30 of Set 1 | kalininsk
# Processing Record 31 of Set 1 | ugoofaaru
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | sayyan
# Processing Record 34 of Set 1 | pointe-noire
# Processing Record 35 of Set 1 | lola
# Processing Record 36 of Set 1 | saint-pierre
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | bonavista
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | juruti
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | caravelas
# Processing Record 48 of Set 1 | mezhevoy
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | sao jose da coroa grande
# Processing Record 1 of Set 2 | lesnoye
# Processing Record 2 of Set 2 | stephenville
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | amapa
# Processing Record 5 of Set 2 | zabol
# Processing Record 6 of Set 2 | camacha
# Processing Record 7 of Set 2 | ormara
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | lodwar
# Processing Record 10 of Set 2 | port blair
# Processing Record 11 of Set 2 | maragogi
# Processing Record 12 of Set 2 | cockburn town
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | hualmay
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | codrington
# Processing Record 17 of Set 2 | hornepayne
# Processing Record 18 of Set 2 | qasigiannguit
# Processing Record 19 of Set 2 | businga
# Processing Record 20 of Set 2 | marseille
# Processing Record 21 of Set 2 | shetpe
# Processing Record 22 of Set 2 | parauna
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | kousseri
# Processing Record 25 of Set 2 | bouna
# Processing Record 26 of Set 2 | talnakh
# Processing Record 27 of Set 2 | nevers
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | teghra
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | quatre cocos
# Processing Record 32 of Set 2 | jalu
# Processing Record 33 of Set 2 | puerto carreno
# Processing Record 34 of Set 2 | sao joao da barra
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | pontes e lacerda
# Processing Record 38 of Set 2 | necochea
# Processing Record 39 of Set 2 | laguna
# Processing Record 40 of Set 2 | mocuba
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | ndele
# Processing Record 43 of Set 2 | tranas
# Processing Record 44 of Set 2 | khakhea
# Processing Record 45 of Set 2 | cefalu
# Processing Record 46 of Set 2 | ostrovnoy
# Processing Record 47 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | suleja
# Processing Record 49 of Set 2 | bahia honda
# Processing Record 50 of Set 2 | general roca
# Processing Record 1 of Set 3 | pitelino
# Processing Record 2 of Set 3 | chinsali
# Processing Record 3 of Set 3 | san-pedro
# Processing Record 4 of Set 3 | belyy yar
# Processing Record 5 of Set 3 | mumbwa
# Processing Record 6 of Set 3 | hammerfest
# Processing Record 7 of Set 3 | dolores
# Processing Record 8 of Set 3 | maloyaroslavets
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | guiberoua
# Processing Record 13 of Set 3 | aguimes
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | hwange
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | luau
# Processing Record 19 of Set 3 | thunder bay
# Processing Record 20 of Set 3 | ipameri
# Processing Record 21 of Set 3 | ilam
# Processing Record 22 of Set 3 | margate
# Processing Record 23 of Set 3 | ornes
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | barkly west
# Processing Record 26 of Set 3 | sokol
# Processing Record 27 of Set 3 | sorland
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | chapais
# Processing Record 30 of Set 3 | kondoa
# Processing Record 31 of Set 3 | morondava
# Processing Record 32 of Set 3 | uige
# Processing Record 33 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | havre-saint-pierre
# Processing Record 35 of Set 3 | kavaratti
# Processing Record 36 of Set 3 | ondjiva
# Processing Record 37 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 38 of Set 3 | kirkwall
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | karpathos
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | shinpokh
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | takoradi
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | jumla
# Processing Record 1 of Set 4 | lexington
# Processing Record 2 of Set 4 | nantucket
# Processing Record 3 of Set 4 | trujillo
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | nyazepetrovsk
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | nesna
# Processing Record 8 of Set 4 | arrecife
# Processing Record 9 of Set 4 | marienburg
# Processing Record 10 of Set 4 | liverpool
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | marzuq
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | harare
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | coutances
# Processing Record 18 of Set 4 | saint-francois
# Processing Record 19 of Set 4 | ornskoldsvik
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | cotonou
# Processing Record 22 of Set 4 | cordoba
# Processing Record 23 of Set 4 | marquette
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | orahovac
# Processing Record 27 of Set 4 | rio grande
# Processing Record 28 of Set 4 | arona
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | loiza
# Processing Record 31 of Set 4 | zapolyarnyy
# Processing Record 32 of Set 4 | yokadouma
# Processing Record 33 of Set 4 | coxim
# Processing Record 34 of Set 4 | sete lagoas
# Processing Record 35 of Set 4 | karoi
# Processing Record 36 of Set 4 | dwarka
# Processing Record 37 of Set 4 | karwar
# Processing Record 38 of Set 4 | georgetown
# Processing Record 39 of Set 4 | puerto cabezas
# Processing Record 40 of Set 4 | slantsy
# Processing Record 41 of Set 4 | avrille
# Processing Record 42 of Set 4 | velikie luki
# City not found. Skipping...
# Processing Record 43 of Set 4 | komsomolskiy
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | mehamn
# Processing Record 46 of Set 4 | clarence town
# Processing Record 47 of Set 4 | mana
# Processing Record 48 of Set 4 | aquiraz
# Processing Record 49 of Set 4 | conceicao do araguaia
# Processing Record 50 of Set 4 | krasnoborsk
# Processing Record 1 of Set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 2 of Set 5 | progreso
# Processing Record 3 of Set 5 | mecca
# Processing Record 4 of Set 5 | ostrow mazowiecka
# Processing Record 5 of Set 5 | crossville
# Processing Record 6 of Set 5 | garowe
# Processing Record 7 of Set 5 | bubaque
# Processing Record 8 of Set 5 | abalak
# Processing Record 9 of Set 5 | soldatskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | mastic beach
# Processing Record 11 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 5 | coihaique
# Processing Record 13 of Set 5 | oranjemund
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | andra
# Processing Record 17 of Set 5 | buta
# Processing Record 18 of Set 5 | kez
# Processing Record 19 of Set 5 | san juan
# Processing Record 20 of Set 5 | serenje
# Processing Record 21 of Set 5 | beyneu
# Processing Record 22 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | serro
# Processing Record 24 of Set 5 | arlit
# Processing Record 25 of Set 5 | kabo
# Processing Record 26 of Set 5 | vengerovo
# Processing Record 27 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 5 | ipanema
# Processing Record 29 of Set 5 | florianopolis
# Processing Record 30 of Set 5 | carutapera
# Processing Record 31 of Set 5 | rio gallegos
# Processing Record 32 of Set 5 | bereznik
# Processing Record 33 of Set 5 | kasongo-lunda
# Processing Record 34 of Set 5 | matay
# Processing Record 35 of Set 5 | apt
# Processing Record 36 of Set 5 | kholm
# Processing Record 37 of Set 5 | kurara
# Processing Record 38 of Set 5 | chardara
# Processing Record 39 of Set 5 | isla mujeres
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | kashi
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | raudeberg
# Processing Record 44 of Set 5 | conde
# Processing Record 45 of Set 5 | la libertad
# Processing Record 46 of Set 5 | acarau
# Processing Record 47 of Set 5 | kidal
# Processing Record 48 of Set 5 | manthani
# Processing Record 49 of Set 5 | antofagasta
# Processing Record 50 of Set 5 | birao
# Processing Record 1 of Set 6 | jaisalmer
# Processing Record 2 of Set 6 | kaabong
# Processing Record 3 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 6 | bocaiuva
# Processing Record 5 of Set 6 | bilma
# Processing Record 6 of Set 6 | birjand
# Processing Record 7 of Set 6 | aksarka
# Processing Record 8 of Set 6 | irpa irpa
# Processing Record 9 of Set 6 | korem
# Processing Record 10 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 11 of Set 6 | maridi
# Processing Record 12 of Set 6 | akdepe
# Processing Record 13 of Set 6 | saint-joseph
# Processing Record 14 of Set 6 | albania
# Processing Record 15 of Set 6 | knysna
# Processing Record 16 of Set 6 | lochwinnoch
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | harindanga
# Processing Record 19 of Set 6 | kuzino
# Processing Record 20 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | bartica
# Processing Record 22 of Set 6 | saint anthony
# Processing Record 23 of Set 6 | antalaha
# Processing Record 24 of Set 6 | kochevo
# Processing Record 25 of Set 6 | halifax
# Processing Record 26 of Set 6 | glencoe
# Processing Record 27 of Set 6 | sergeyevka
# Processing Record 28 of Set 6 | the valley
# Processing Record 29 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 30 of Set 6 | sharjah
# Processing Record 31 of Set 6 | korcula
# Processing Record 32 of Set 6 | dalbandin
# Processing Record 33 of Set 6 | hamilton
# Processing Record 34 of Set 6 | colesberg
# Processing Record 35 of Set 6 | mbuji-mayi
# Processing Record 36 of Set 6 | simiti
# Processing Record 37 of Set 6 | markala
# Processing Record 38 of Set 6 | hazorasp
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | novozavidovskiy
# Processing Record 41 of Set 6 | ponta delgada
# Processing Record 42 of Set 6 | mapiripan
# Processing Record 43 of Set 6 | iguape
# Processing Record 44 of Set 6 | kolar
# Processing Record 45 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 6 | karasjok
# Processing Record 48 of Set 6 | luanda
# Processing Record 49 of Set 6 | igarape-miri
# City not found. Skipping...
# Processing Record 50 of Set 6 | el alto
# Processing Record 1 of Set 7 | silale
# Processing Record 2 of Set 7 | karpuninskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | tornio
# Processing Record 4 of Set 7 | nara
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | saint-augustin
# Processing Record 7 of Set 7 | farafangana
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | santa ana
# Processing Record 10 of Set 7 | wladyslawowo
# Processing Record 11 of Set 7 | ambanja
# Processing Record 12 of Set 7 | boksburg
# Processing Record 13 of Set 7 | moose factory
# Processing Record 14 of Set 7 | santa cruz
# Processing Record 15 of Set 7 | witrivier
# City not found. Skipping...
# Processing Record 16 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 7 | ananas
# Processing Record 18 of Set 7 | cutro
# Processing Record 19 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 7 | sal rei
# Processing Record 22 of Set 7 | valkeala
# Processing Record 23 of Set 7 | san felipe
# Processing Record 24 of Set 7 | tolmachevo
# Processing Record 25 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 7 | zilupe
# Processing Record 27 of Set 7 | kapoeta
# Processing Record 28 of Set 7 | razole
# Processing Record 29 of Set 7 | turbat
# Processing Record 30 of Set 7 | oistins
# Processing Record 31 of Set 7 | yar-sale
# Processing Record 32 of Set 7 | ankazoabo
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | leshukonskoye
# Processing Record 35 of Set 7 | tobati
# Processing Record 36 of Set 7 | mehriz
# Processing Record 37 of Set 7 | mayumba
# Processing Record 38 of Set 7 | amalapuram
# Processing Record 39 of Set 7 | paita
# Processing Record 40 of Set 7 | parana
# Processing Record 41 of Set 7 | mingaora
# Processing Record 42 of Set 7 | karjat
# Processing Record 43 of Set 7 | sortavala
# Processing Record 44 of Set 7 | ferrol
# Processing Record 45 of Set 7 | bereda
# Processing Record 46 of Set 7 | rabo de peixe
# Processing Record 47 of Set 7 | lucea
# Processing Record 48 of Set 7 | ganesti
# Processing Record 49 of Set 7 | nador
# Processing Record 50 of Set 7 | kutum
# Processing Record 1 of Set 8 | zhezkazgan
# Processing Record 2 of Set 8 | puerto ayora
# Processing Record 3 of Set 8 | samarkand
# Processing Record 4 of Set 8 | awbari
# Processing Record 5 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 8 | kamenka
# Processing Record 7 of Set 8 | kermanshah
# Processing Record 8 of Set 8 | carbonia
# Processing Record 9 of Set 8 | zyryanskoye
# Processing Record 10 of Set 8 | berlevag
# Processing Record 11 of Set 8 | sargatskoye
# Processing Record 12 of Set 8 | nikki
# Processing Record 13 of Set 8 | olden
# Processing Record 14 of Set 8 | priiskovyy
# Processing Record 15 of Set 8 | buchanan
# Processing Record 16 of Set 8 | punta arenas
# Processing Record 17 of Set 8 | stranda
# Processing Record 18 of Set 8 | nikel
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | tete
# Processing Record 21 of Set 8 | paratinga
# Processing Record 22 of Set 8 | lasa
# Processing Record 23 of Set 8 | shahreza
# Processing Record 24 of Set 8 | iracoubo
# Processing Record 25 of Set 8 | svirstroy
# Processing Record 26 of Set 8 | sheffield
# Processing Record 27 of Set 8 | salinopolis
# Processing Record 28 of Set 8 | sawakin
# Processing Record 29 of Set 8 | richards bay
# Processing Record 30 of Set 8 | cap malheureux
# Processing Record 31 of Set 8 | hrob
# Processing Record 32 of Set 8 | phalaborwa
# Processing Record 33 of Set 8 | vesoul
# Processing Record 34 of Set 8 | pokhara
# Processing Record 35 of Set 8 | tiznit
# Processing Record 36 of Set 8 | urucara
# Processing Record 37 of Set 8 | honningsvag
# Processing Record 38 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 8 | hobyo
# Processing Record 40 of Set 8 | riyadh
# Processing Record 41 of Set 8 | bardiyah
# Processing Record 42 of Set 8 | saint-leu
# Processing Record 43 of Set 8 | dubai
# Processing Record 44 of Set 8 | ghanzi
# Processing Record 45 of Set 8 | puerto del rosario
# Processing Record 46 of Set 8 | sikasso
# Processing Record 47 of Set 8 | monrovia
# Processing Record 48 of Set 8 | aksu
# Processing Record 49 of Set 8 | killybegs
# Processing Record 50 of Set 8 | shu
# Processing Record 1 of Set 9 | ofaqim
# Processing Record 2 of Set 9 | muscat
# Processing Record 3 of Set 9 | camana
# Processing Record 4 of Set 9 | bandundu
# Processing Record 5 of Set 9 | ayni
# Processing Record 6 of Set 9 | meulaboh
# Processing Record 7 of Set 9 | abnub
# Processing Record 8 of Set 9 | tupi paulista
# Processing Record 9 of Set 9 | taoudenni
# Processing Record 10 of Set 9 | aswan
# Processing Record 11 of Set 9 | izhma
# Processing Record 12 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 9 | pimentel
# Processing Record 14 of Set 9 | bauchi
# Processing Record 15 of Set 9 | aktas
# Processing Record 16 of Set 9 | muros
# Processing Record 17 of Set 9 | beboto
# Processing Record 18 of Set 9 | tutoia
# Processing Record 19 of Set 9 | adre
# Processing Record 20 of Set 9 | tucuma
# Processing Record 21 of Set 9 | alta
# Processing Record 22 of Set 9 | marystown
# Processing Record 23 of Set 9 | tenenkou
# Processing Record 24 of Set 9 | sinnamary
# Processing Record 25 of Set 9 | le locle
# Processing Record 26 of Set 9 | husavik
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | odesskoye
# Processing Record 29 of Set 9 | senj
# Processing Record 30 of Set 9 | puerto colombia
# Processing Record 31 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 32 of Set 9 | axim
# Processing Record 33 of Set 9 | verdun
# Processing Record 34 of Set 9 | itarema
# Processing Record 35 of Set 9 | biltine
# Processing Record 36 of Set 9 | kaka
# Processing Record 37 of Set 9 | garoua
# Processing Record 38 of Set 9 | dvinskoy
# Processing Record 39 of Set 9 | beloha
# Processing Record 40 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 9 | sumbe
# Processing Record 42 of Set 9 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 43 of Set 9 | viedma
# Processing Record 44 of Set 9 | inta
# Processing Record 45 of Set 9 | harper
# Processing Record 46 of Set 9 | laureles
# Processing Record 47 of Set 9 | mbanza-ngungu
# Processing Record 48 of Set 9 | santa isabel do rio negro
# Processing Record 49 of Set 9 | tazovskiy
# Processing Record 50 of Set 9 | frontino
# Processing Record 1 of Set 10 | gualeguaychu
# Processing Record 2 of Set 10 | kerzhenets
# City not found. Skipping...
# Processing Record 3 of Set 10 | iskateley
# Processing Record 4 of Set 10 | khorramshahr
# Processing Record 5 of Set 10 | roxana
# Processing Record 6 of Set 10 | gat
# Processing Record 7 of Set 10 | upata
# Processing Record 8 of Set 10 | yabrud
# Processing Record 9 of Set 10 | ambato
# Processing Record 10 of Set 10 | srivardhan
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | tefe
# Processing Record 13 of Set 10 | ust-koksa
# Processing Record 14 of Set 10 | tbilisskaya
# Processing Record 15 of Set 10 | gambissara
# Processing Record 16 of Set 10 | brodnica
# Processing Record 17 of Set 10 | filadelfia
# Processing Record 18 of Set 10 | roald
# Processing Record 19 of Set 10 | tahta
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | troitskoye
# Processing Record 22 of Set 10 | nuuk
# Processing Record 23 of Set 10 | buraydah
# Processing Record 24 of Set 10 | viransehir
# Processing Record 25 of Set 10 | cajaruro
# Processing Record 26 of Set 10 | marsaxlokk
# Processing Record 27 of Set 10 | tolstoy-yurt
# Processing Record 28 of Set 10 | choma
# Processing Record 29 of Set 10 | ciudad guayana
# Processing Record 30 of Set 10 | matagami
# Processing Record 31 of Set 10 | dudinka
# Processing Record 32 of Set 10 | batticaloa
# Processing Record 33 of Set 10 | lixourion
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | sabalgarh
# Processing Record 36 of Set 10 | ngama
# Processing Record 37 of Set 10 | marysville
# Processing Record 38 of Set 10 | cruzilia
# Processing Record 39 of Set 10 | saint-pascal
# City not found. Skipping...
# Processing Record 40 of Set 10 | tessalit
# Processing Record 41 of Set 10 | qena
# Processing Record 42 of Set 10 | luena
# Processing Record 43 of Set 10 | ushtobe
# Processing Record 44 of Set 10 | mount pleasant
# Processing Record 45 of Set 10 | union
# Processing Record 46 of Set 10 | bavleny
# Processing Record 47 of Set 10 | rawson
# Processing Record 48 of Set 10 | dovers
# Processing Record 49 of Set 10 | cururupu
# Processing Record 50 of Set 10 | kyshtovka
# Processing Record 1 of Set 11 | hambantota
# Processing Record 2 of Set 11 | awjilah
# Processing Record 3 of Set 11 | okakarara
# Processing Record 4 of Set 11 | krasnoselkup
# Processing Record 5 of Set 11 | staryy nadym
# Processing Record 6 of Set 11 | tombouctou
# Processing Record 7 of Set 11 | coari
# Processing Record 8 of Set 11 | porto recanati
# Processing Record 9 of Set 11 | sfantu gheorghe
# Processing Record 10 of Set 11 | warmbad
# Processing Record 11 of Set 11 | benghazi
# Processing Record 12 of Set 11 | beni suef
# Processing Record 13 of Set 11 | olafsvik
# Processing Record 14 of Set 11 | mitsamiouli
# Processing Record 15 of Set 11 | puerto suarez
# Processing Record 16 of Set 11 | sao felix do xingu
# Processing Record 17 of Set 11 | manakara
# Processing Record 18 of Set 11 | naifaru
# Processing Record 19 of Set 11 | panaba
# Processing Record 20 of Set 11 | bet shemesh
# Processing Record 21 of Set 11 | otukpo
# Processing Record 22 of Set 11 | henties bay
# Processing Record 23 of Set 11 | sur
# Processing Record 24 of Set 11 | haverhill
# Processing Record 25 of Set 11 | san bartolome de tirajana
# Processing Record 26 of Set 11 | aberfoyle
# Processing Record 27 of Set 11 | little current
# Processing Record 28 of Set 11 | mustvee
# Processing Record 29 of Set 11 | arak
# Processing Record 30 of Set 11 | ancud
# Processing Record 31 of Set 11 | hellvik
# Processing Record 32 of Set 11 | moissala
# Processing Record 33 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 11 | khlevnoye
# Processing Record 35 of Set 11 | mizdah
# Processing Record 36 of Set 11 | savasleyka
# Processing Record 37 of Set 11 | sembe
# Processing Record 38 of Set 11 | saquarema
# Processing Record 39 of Set 11 | libreville
# Processing Record 40 of Set 11 | comodoro rivadavia
# Processing Record 41 of Set 11 | paso de los toros
# Processing Record 42 of Set 11 | lafiagi
# Processing Record 43 of Set 11 | goderich
# Processing Record 44 of Set 11 | boyabat
# Processing Record 45 of Set 11 | bhag
# Processing Record 46 of Set 11 | levokumskoye
# Processing Record 47 of Set 11 | torquay
# Processing Record 48 of Set 11 | vallenar
# Processing Record 49 of Set 11 | aracati
# Processing Record 50 of Set 11 | plettenberg bay
# Processing Record 1 of Set 12 | ilo
# Processing Record 2 of Set 12 | mumford
# Processing Record 3 of Set 12 | tibati
# Processing Record 4 of Set 12 | muli
# Processing Record 5 of Set 12 | lima
# Processing Record 6 of Set 12 | lisakovsk
# Processing Record 7 of Set 12 | soyo
# Processing Record 8 of Set 12 | comrat
# Processing Record 9 of Set 12 | tromso
# Processing Record 10 of Set 12 | muravlenko
# Processing Record 11 of Set 12 | oulainen
# Processing Record 12 of Set 12 | mayuge
# Processing Record 13 of Set 12 | gemena
# Processing Record 14 of Set 12 | faya
# Processing Record 15 of Set 12 | nurota
# Processing Record 16 of Set 12 | ajdabiya
# Processing Record 17 of Set 12 | curaca
# Processing Record 18 of Set 12 | rocha
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | braslav
# City not found. Skipping...
# Processing Record 21 of Set 12 | jena
# Processing Record 22 of Set 12 | ibra
# Processing Record 23 of Set 12 | turukhansk
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | raga
# Processing Record 26 of Set 12 | mbacke
# City not found. Skipping...
# Processing Record 27 of Set 12 | terenos
# Processing Record 28 of Set 12 | bugulma
# Processing Record 29 of Set 12 | sennoy
# Processing Record 30 of Set 12 | adrar
# Processing Record 31 of Set 12 | los llanos de aridane
# Processing Record 32 of Set 12 | montalvo
# Processing Record 33 of Set 12 | loughrea
# Processing Record 34 of Set 12 | kachiry
# Processing Record 35 of Set 12 | shubarshi
# Processing Record 36 of Set 12 | porto novo
# Processing Record 37 of Set 12 | vuktyl
# Processing Record 38 of Set 12 | nardaran
# Processing Record 39 of Set 12 | jijiga
# Processing Record 40 of Set 12 | montepuez
# Processing Record 41 of Set 12 | kollam
# Processing Record 42 of Set 12 | qaqortoq
# Processing Record 43 of Set 12 | lumeje
# Processing Record 44 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 45 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 46 of Set 12 | uelzen
# Processing Record 47 of Set 12 | cape canaveral
# Processing Record 48 of Set 12 | xanlar
# Processing Record 49 of Set 12 | nouakchott
# Processing Record 50 of Set 12 | kibaya
# Processing Record 1 of Set 13 | santa ines
# Processing Record 2 of Set 13 | abu dhabi
# Processing Record 3 of Set 13 | piacabucu
# Processing Record 4 of Set 13 | zhanaozen
# Processing Record 5 of Set 13 | jibuti
# Processing Record 6 of Set 13 | bodden town
# Processing Record 7 of Set 13 | dhidhdhoo
# Processing Record 8 of Set 13 | pindushi
# Processing Record 9 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 13 | calabozo
# Processing Record 11 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 13 | brae
# Processing Record 13 of Set 13 | kuybyshevo
# Processing Record 14 of Set 13 | andenes
# Processing Record 15 of Set 13 | kangaatsiaq
# Processing Record 16 of Set 13 | paamiut
# Processing Record 17 of Set 13 | asosa
# Processing Record 18 of Set 13 | krutinka
# Processing Record 19 of Set 13 | chitral
# Processing Record 20 of Set 13 | lannion
# Processing Record 21 of Set 13 | jonkoping
# Processing Record 22 of Set 13 | bonanza
# Processing Record 23 of Set 13 | stonehaven
# Processing Record 24 of Set 13 | igrim
# Processing Record 25 of Set 13 | diebougou
# Processing Record 26 of Set 13 | alta floresta
# Processing Record 27 of Set 13 | lusambo
# Processing Record 28 of Set 13 | mananjary
# Processing Record 29 of Set 13 | grand-bourg
# Processing Record 30 of Set 13 | corinto
# Processing Record 31 of Set 13 | aras
# Processing Record 32 of Set 13 | portsmouth
# Processing Record 33 of Set 13 | mwinilunga
# Processing Record 34 of Set 13 | maceio
# Processing Record 35 of Set 13 | mehran
# Processing Record 36 of Set 13 | hofn
# Processing Record 37 of Set 13 | marsa matruh
# Processing Record 38 of Set 13 | eluru
# Processing Record 39 of Set 13 | chupa
# Processing Record 40 of Set 13 | barcelos
# Processing Record 41 of Set 13 | badarwas
# Processing Record 42 of Set 13 | deskati
# Processing Record 43 of Set 13 | kintampo
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | wawa
# Processing Record 46 of Set 13 | jam sahib
# Processing Record 47 of Set 13 | port-cartier
# Processing Record 48 of Set 13 | bom jardim
# Processing Record 49 of Set 13 | stromness
# Processing Record 50 of Set 13 | lodeynoye pole
# Processing Record 1 of Set 14 | butterworth
# Processing Record 2 of Set 14 | cabedelo
# Processing Record 3 of Set 14 | najran
# Processing Record 4 of Set 14 | boueni
# Processing Record 5 of Set 14 | maxixe
# Processing Record 6 of Set 14 | varnamo
# Processing Record 7 of Set 14 | afua
# Processing Record 8 of Set 14 | letlhakeng
# Processing Record 9 of Set 14 | oksovskiy
# Processing Record 10 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 11 of Set 14 | neuquen
# Processing Record 12 of Set 14 | portree
# Processing Record 13 of Set 14 | milove
# Processing Record 14 of Set 14 | zernograd
# Processing Record 15 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 14 | moroni
# Processing Record 17 of Set 14 | lagos
# Processing Record 18 of Set 14 | kayankulam
# Processing Record 19 of Set 14 | ambovombe
# Processing Record 20 of Set 14 | kolosovka
# Processing Record 21 of Set 14 | uri
# Processing Record 22 of Set 14 | uvira
# Processing Record 23 of Set 14 | bokoro
# Processing Record 24 of Set 14 | alekseyevka
# Processing Record 25 of Set 14 | komsomolets
# Processing Record 26 of Set 14 | khomeyn
# Processing Record 27 of Set 14 | bull savanna
# Processing Record 28 of Set 14 | ipixuna
# Processing Record 29 of Set 14 | kankon
# Processing Record 30 of Set 14 | ruyigi
# Processing Record 31 of Set 14 | nieuw amsterdam
# Processing Record 32 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 14 | primorsk
# Processing Record 34 of Set 14 | el vendrell
# Processing Record 35 of Set 14 | pulaski
# Processing Record 36 of Set 14 | grindavik
# Processing Record 37 of Set 14 | zlocieniec
# Processing Record 38 of Set 14 | altamira
# Processing Record 39 of Set 14 | ape
# Processing Record 40 of Set 14 | thyboron
# Processing Record 41 of Set 14 | kadyy
# Processing Record 42 of Set 14 | koroni
# Processing Record 43 of Set 14 | kazerun
# Processing Record 44 of Set 14 | monte santo de minas
# Processing Record 45 of Set 14 | sao felipe
# Processing Record 46 of Set 14 | angoche
# Processing Record 47 of Set 14 | gandai
# Processing Record 48 of Set 14 | bagotville
# Processing Record 49 of Set 14 | altay
# Processing Record 50 of Set 14 | olaine
# Processing Record 1 of Set 15 | kondopoga
# Processing Record 2 of Set 15 | correntina
# Processing Record 3 of Set 15 | ifakara
# Processing Record 4 of Set 15 | bayir
# Processing Record 5 of Set 15 | wajir
# Processing Record 6 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 15 | glamoc
# Processing Record 8 of Set 15 | tabatinga
# Processing Record 9 of Set 15 | synya
# Processing Record 10 of Set 15 | thompson
# Processing Record 11 of Set 15 | meiganga
# Processing Record 12 of Set 15 | grootfontein
# Processing Record 13 of Set 15 | duz
# City not found. Skipping...
# Processing Record 14 of Set 15 | naryan-mar
# Processing Record 15 of Set 15 | fort atkinson
# Processing Record 16 of Set 15 | umm lajj
# Processing Record 17 of Set 15 | sisimiut
# Processing Record 18 of Set 15 | pangody
# Processing Record 19 of Set 15 | crotone
# Processing Record 20 of Set 15 | marsh harbour
# Processing Record 21 of Set 15 | mogadouro
# Processing Record 22 of Set 15 | rebrikha
# Processing Record 23 of Set 15 | iquitos
# Processing Record 24 of Set 15 | teya
# Processing Record 25 of Set 15 | sabha
# Processing Record 26 of Set 15 | lake city
# Processing Record 27 of Set 15 | madison
# Processing Record 28 of Set 15 | manyana
# Processing Record 29 of Set 15 | la palma
# Processing Record 30 of Set 15 | lokosovo
# Processing Record 31 of Set 15 | kananga
# Processing Record 32 of Set 15 | rudbar
# Processing Record 33 of Set 15 | presidencia roque saenz pena
# Processing Record 34 of Set 15 | khristoforovo
# City not found. Skipping...
# Processing Record 35 of Set 15 | jhalida
# Processing Record 36 of Set 15 | bunia
# Processing Record 37 of Set 15 | ariquemes
# Processing Record 38 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 15 | gazli
# Processing Record 40 of Set 15 | la asuncion
# Processing Record 41 of Set 15 | boysun
# Processing Record 42 of Set 15 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | walvis bay
# Processing Record 44 of Set 15 | senanga
# Processing Record 45 of Set 15 | brigantine
# Processing Record 46 of Set 15 | palmetto
# Processing Record 47 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 48 of Set 15 | surgut
# Processing Record 49 of Set 15 | ylojarvi
# Processing Record 50 of Set 15 | kurya
# Processing Record 1 of Set 16 | hatillo
# Processing Record 2 of Set 16 | inirida
# Processing Record 3 of Set 16 | soria
# Processing Record 4 of Set 16 | areosa
# Processing Record 5 of Set 16 | baiao
# Processing Record 6 of Set 16 | rajshahi
# Processing Record 7 of Set 16 | palma
# Processing Record 8 of Set 16 | vardenis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
WeatherPy_Database = pd.DataFrame(city_data)

# %%
WeatherPy_Database
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Alto Longa  -5.2511 -42.2103    104.18        17          61
# 1    Saint-Philippe -21.3585  55.7679     69.39        86          61
# 2           Ushuaia -54.8000 -68.3000     42.46        49          75
# 3         Polyarnyy  69.1989  33.4478     46.99        98         100
# 4         Cape Town -33.9258  18.4232     61.27        77          20
# ..              ...      ...      ...       ...       ...         ...
# 698          Areosa  41.7178  -8.8571     69.24        80           3
# 699           Baiao  -2.7906 -49.6717    100.24        29          48
# 700        Rajshahi  24.3667  88.6000     80.55        86          95
# 701           Palma  39.5694   2.6502     80.40        76          40
# 702        Vardenis  40.1827  45.7311     54.34        65           8
#
#      Wind Speed Country                 Date Current Description
# 0          4.88      BR  2022-09-16 18:18:23       broken clouds
# 1         15.68      RE  2022-09-16 18:18:23          light rain
# 2         10.36      AR  2022-09-16 18:14:12       broken clouds
# 3         12.57      RU  2022-09-16 18:18:24     overcast clouds
# 4          6.91      ZA  2022-09-16 18:15:22          few clouds
# ..          ...     ...                  ...                 ...
# 698        5.86      PT  2022-09-16 18:23:08           clear sky
# 699        5.26      BR  2022-09-16 18:23:08    scattered clouds
# 700        6.33      BD  2022-09-16 18:23:09     overcast clouds
# 701        3.44      ES  2022-09-16 18:21:12    scattered clouds
# 702        4.63      AM  2022-09-16 18:23:10           clear sky
#
# [703 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database.to_csv(output_data_file, index_label="City_ID")
